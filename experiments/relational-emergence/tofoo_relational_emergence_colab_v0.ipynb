# %% [markdown]
# # TOFOO Relational Emergence — Colab v0
#
# Falsification-first test of whether a persistent relational field can create capability beyond the best isolated participant and a pooled-raw control.
#
# Primary metric: `relational - max(isolated_max, pooled_raw)`

# %%
# !pip -q install -U transformers accelerate bitsandbytes

# %% [markdown]
# ## Get the private repo
#
# If cloning below asks for authentication, add a Colab secret named `GITHUB_TOKEN` with read access to `nsolland/Valo-Twin`, then rerun this cell. The token is used only at runtime and is not written into the notebook.

# %%
from pathlib import Path
import os, subprocess
repo = Path('/content/Valo-Twin')
if not repo.exists():
    clone_url = 'https://github.com/nsolland/Valo-Twin.git'
    try:
        from google.colab import userdata
        token = userdata.get('GITHUB_TOKEN')
    except Exception:
        token = None
    if token:
        clone_url = f'https://x-access-token:{token}@github.com/nsolland/Valo-Twin.git'
    subprocess.run(['git','clone','--depth','1','--branch','main',clone_url,str(repo)], check=True)
os.chdir(repo)
print('repo:', repo)
print('branch:', subprocess.check_output(['git','branch','--show-current'], text=True).strip())

# %% [markdown]
# ## 0. Machinery check — no research evidence

# %%
# !python experiments/relational-emergence/relational_emergence_v0.py --mock --worlds 3

# %% [markdown]
# ## 1. First real free-Colab run
#
# Use **Runtime → Change runtime type → GPU** first.

# %%
# !python experiments/relational-emergence/relational_emergence_v0.py \
  --worlds 3 \
  --participants 3 \
  --rounds 2 \
  --model-a Qwen/Qwen2.5-1.5B-Instruct

# %% [markdown]
# ## 2. Inspect evidence

# %%
import json
from pathlib import Path
out = Path('/content/tofoo_relational_results')
for name in ['manifest.json','summary.json','fields.json']:
    p = out / name
    print('\n###', name)
    print(json.dumps(json.loads(p.read_text()), indent=2) if p.exists() else 'missing')

# %% [markdown]
# ## 3. Optional substrate-replacement run
#
# Build the governed relational field with 1.5B, discard model-local state, then test the preserved field with 3B.

# %%
# !python experiments/relational-emergence/relational_emergence_v0.py \
  --worlds 3 \
  --participants 3 \
  --rounds 2 \
  --replacement \
  --model-a Qwen/Qwen2.5-1.5B-Instruct \
  --model-b Qwen/Qwen2.5-3B-Instruct

# %% [markdown]
# ### Interpretation guardrail
#
# v0 is a signal-discovery run only. A research claim requires more worlds/seeds, normalized inference budgets, frozen holdouts and independent reproduction.
